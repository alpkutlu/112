# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Read the CSV file with the correct delimiter

# %%
df = pd.read_csv('Marketing-bank.csv', delimiter=';')

# %% [markdown]
# Map month names to numeric values for proper sorting

# %%
month_mapping = {'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
                 'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12}

# %%
df['Month'] = df['Month'].map(month_mapping)

# %% [markdown]
# Sort the DataFrame by the numeric month values to ensure the correct order in the plot

# %%
df = df.sort_values(by='Month')

# %% [markdown]
# Create a bar plot of average response rate by month

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Month', y='Conversion_Rate', data=df, ci=None, palette='viridis', capsize=0, order=range(1, 13))
plt.title('Average Response Rate by Month')
plt.xlabel('Month')
plt.ylabel('Average Conversion Rate')
plt.xticks(ticks=range(0, 12), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
