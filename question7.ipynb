# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv(r"C:\Users\lasto\PycharmProjects\pythonProject\.venv\Marketing-bank.csv", delimiter=";")
#  Group by 'CampaignType' and sum the spendings
grouped_data = df.groupby('Campaign_Type')['Total_Spending'].sum().reset_index()
# Plot the scatter plot using df.plot command
df.plot(kind="scatter", x = "Yearly_Income", y = "Account_Balance")
# setting the titles and labels for clarity
plt.title("Account Balance vs Yearly Income")
plt.xlabel("Yearly_Income")
plt.ylabel("Account_Balance")
# Out:
# Text(0, 0.5, 'Account_Balance')
